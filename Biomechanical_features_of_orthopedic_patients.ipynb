# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Deepak Raj\Desktop\Data_Science\Machine Learning\Data\column_2C_weka.csv')

# %%
df
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 0           63.027818            22.552586              39.609117
# 1           39.056951            10.060991              25.015378
# 2           68.832021            22.218482              50.092194
# 3           69.297008            24.652878              44.311238
# 4           49.712859             9.652075              28.317406
# ..                ...                  ...                    ...
# 305         47.903565            13.616688              36.000000
# 306         53.936748            20.721496              29.220534
# 307         61.446597            22.694968              46.170347
# 308         45.252792             8.693157              41.583126
# 309         33.841641             5.073991              36.641233
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 0       40.475232      98.672917                 -0.254400  Abnormal
# ...

# %% [markdown]
# ## Basic checks

# %%
#description about given dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt numeric       310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
#shape of given dataset
df.shape
# Out:
# (310, 7)

# %%
# Total no of rows is 310
# Total no of columns is 7

# %%
#statistical information about numerical data
df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# count        310.000000           310.000000             310.000000
# mean          60.496653            17.542822              51.930930
# std           17.236520            10.008330              18.554064
# min           26.147921            -6.554948              14.000000
# 25%           46.430294            10.667069              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.877696            22.120395              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# ...

# %%
#statistical information about categorical data
df.describe(include='O')
# Out:
#            class
# count        310
# unique         2
# top     Abnormal
# freq         210

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Data

# %%
import sweetviz
sz=sweetviz.analyze(df)
sz.show_notebook()
# Out:
# ...
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
df.loc[:,'class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
sns.countplot(x='class',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
#No of abnormal patient is 210
#No of normal patient is 100

# %% [markdown]
# ### Bivariate Data

# %%
plt.figure(figsize=(20,25), facecolor='white')# defining  canvas size
plotnumber = 1 # initializing plotnumber variable to 1 it will maintain the count of how many graph is going to plot in canvas 


for column in df: # iteration of columns / acessing the columns from  dataset 
    if plotnumber<=7 :     # as there are 7 columns in the data
        ax = plt.subplot(3,3,plotnumber)# plotting 7 graphs (3-rows,3-columns) ,plotnumber is for count  
        sns.histplot(x=df[column],hue=df.loc[:,'class']) ## it give frequency hue =value counts
        plt.xlabel(column,fontsize=20) #assigning name to x-axis and "name" font size is 20
        plt.ylabel('class',fontsize=20)#assigning name to y-axis and "name" font size is 20
    plotnumber+=1 # increment of plotnumber 
plt.show()# to show graph

# %%
sns.scatterplot(x='pelvic_incidence',y='pelvic_tilt numeric',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='pelvic_incidence', ylabel='pelvic_tilt numeric'>

# %%
# pelvic_incidence is increasing with increasing with pelvic_tilt numeric
# Abnormal patient is higher

# %%
sns.scatterplot(x='pelvic_incidence',y='lumbar_lordosis_angle',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='pelvic_incidence', ylabel='lumbar_lordosis_angle'>

# %%
# pelvic_incidence is increasing with increasing with lumbar_lordosis_angle
# Abnormal patient is higher

# %%
sns.scatterplot(x='pelvic_incidence',y='sacral_slope',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='pelvic_incidence', ylabel='sacral_slope'>

# %%
# pelvic_incidence is increasing with increasing with sacral_slope
# Abnormal patient is higher

# %%
sns.scatterplot(x='pelvic_incidence',y='degree_spondylolisthesis',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='pelvic_incidence', ylabel='degree_spondylolisthesis'>

# %%
# pelvic_incidence is increasing with increasing with degree_spondylolisthesis
# Abnormal patient is higher

# %%
sns.scatterplot(x='lumbar_lordosis_angle',y='pelvic_tilt numeric',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='lumbar_lordosis_angle', ylabel='pelvic_tilt numeric'>

# %%
# lumbar_lordosis_angle is increasing with increasing with 	pelvic_tilt numeric
# Abnormal patient is higher

# %%
sns.scatterplot(x='lumbar_lordosis_angle',y='sacral_slope',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='lumbar_lordosis_angle', ylabel='sacral_slope'>

# %%
# lumbar_lordosis_angle is increasing with increasing with sacral_slope
# Abnormal patient is higher

# %%
sns.scatterplot(x='lumbar_lordosis_angle',y='degree_spondylolisthesis',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='lumbar_lordosis_angle', ylabel='degree_spondylolisthesis'>

# %%
# lumbar_lordosis_angle is increasing with increasing with degree_spondylolisthesis
# Abnormal patient is higher

# %%
sns.scatterplot(x='sacral_slope',y='lumbar_lordosis_angle',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='sacral_slope', ylabel='lumbar_lordosis_angle'>

# %%
# lumbar_lordosis_angle is increasing with increasing with sacral_slope
# Abnormal patient is higher

# %%
sns.scatterplot(x='sacral_slope',y='degree_spondylolisthesis',data=df,hue='class')
# Out:
# <AxesSubplot:xlabel='sacral_slope', ylabel='degree_spondylolisthesis'>

# %%
# sacral_slope is increasing with increasing with degree_spondylolisthesis
# Abnormal patient is higher

# %% [markdown]
# ## Data Preprocessing

# %%
#null values
df.isnull().sum()
# Out:
# pelvic_incidence            0
# pelvic_tilt numeric         0
# lumbar_lordosis_angle       0
# sacral_slope                0
# pelvic_radius               0
# degree_spondylolisthesis    0
# class                       0
# dtype: int64

# %%
#no null values

# %%
#outliers
box=df[['pelvic_incidence','pelvic_tilt numeric', 'lumbar_lordosis_angle','sacral_slope','pelvic_radius','degree_spondylolisthesis']]
plt.figure(figsize=(5,10), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=7 : # as there are 9 columns in the data
        ax = plt.subplot(6,1,plotnumber)#plotting 6 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=20)#assign name to x-axis and set font-20
     
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
#outlier treatment
df[df.pelvic_incidence>98]
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 115        129.834041             8.404475              48.384057
# 162        118.144655            38.449501              50.838520
# 163        115.923261            37.515436              76.800000
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 115    121.429566     107.690466                418.543082  Abnormal
# 162     79.695154      81.024541                 74.043767  Abnormal
# 163     78.407825     104.698603                 81.198927  Abnormal

# %%
df.pelvic_incidence[(df.pelvic_incidence>98)]=df.pelvic_incidence.mean()
# Out:
# <ipython-input-39-b832b901e0c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pelvic_incidence[(df.pelvic_incidence>98)]=df.pelvic_incidence.mean()

# %%
#rename header
df.rename({'pelvic_tilt numeric' : 'pelvic_tilt_numeric'}, axis=1,inplace=True)

# %%
df[df.pelvic_tilt_numeric>38]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 51          74.433593            41.557331              27.700000
# 65          83.933009            41.286305              62.000000
# 75          70.221452            39.822724              68.118403
# 84          76.326002            42.396204              57.200000
# 117         86.041280            38.750670              47.871405
# 122         80.074914            48.069531              52.403439
# 136         88.024499            39.844669              81.774473
# 141         89.504947            48.903653              72.003423
# 145         85.643787            42.689195              78.750664
# 162         60.496653            38.449501              50.838520
# 179         68.721910            49.431864              68.056012
# 188         85.680950            38.650035              82.680977
# 191         86.472905            40.303766              61.141012
# ...

# %%
df.pelvic_tilt_numeric[(df.pelvic_tilt_numeric>38)]=df.pelvic_tilt_numeric.mean() # replace with mean value
# Out:
# <ipython-input-62-59658414451d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pelvic_tilt_numeric[(df.pelvic_tilt_numeric>38)]=df.pelvic_tilt_numeric.mean()

# %%
df[df.lumbar_lordosis_angle>100]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 74          72.222334            23.077711              91.000000
# 96          96.657315            19.461581              90.211498
# 98          77.655119            22.432950              93.892779
# 139         85.095503            21.069897              91.734792
# 142         85.290173            18.278890             100.744220
# 168         95.382596            24.822631              95.157633
# 184         81.056611            20.801492              91.784495
# 197         58.828379            37.577873             125.742385
# 201         67.513053            33.275590              96.283062
# 202         76.314028            17.542822              93.284863
# 208         87.679087            20.365613              93.822416
# 224         89.834676            22.639217              90.563461
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# ...

# %%
df.lumbar_lordosis_angle[(df.lumbar_lordosis_angle>100)]=df.lumbar_lordosis_angle.mean() # replace with mean value
# Out:
# <ipython-input-66-2d0baff8cdfb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.lumbar_lordosis_angle[(df.lumbar_lordosis_angle>100)]=df.lumbar_lordosis_angle.mean()

# %%
df[df.sacral_slope>80]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 115         60.496653             8.404475              48.384057
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 115    121.429566     107.690466                418.543082  Abnormal

# %%
df.lumbar_lordosis_angle[(df.lumbar_lordosis_angle>80)]=df.lumbar_lordosis_angle.mean() # replace with mean value
# Out:
# <ipython-input-68-0ea01a6ce7fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.lumbar_lordosis_angle[(df.lumbar_lordosis_angle>80)]=df.lumbar_lordosis_angle.mean()

# %%
df[df.pelvic_radius<90]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 9           36.686353             5.010884              41.948751
# 155         66.804796            14.551602              72.084912
# 162         60.496653            17.542822              50.838520
# 167         72.343594            16.420790              59.869012
# 168         95.382596            24.822631              51.535366
# 173         50.825029             9.064729              56.300000
# 177         80.817771            19.238981              61.642451
# 190         43.718262             9.811985              52.000000
# 196         63.772391            12.763385              65.360524
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 9       31.675469      84.241415                  0.664437  Abnormal
# 155     52.253195      82.456038                 41.685474  Abnormal
# 162     79.695154      81.024541                 74.043767  Abnormal
# ...

# %%
df[df.pelvic_radius>145]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 75          70.221452            17.542822              68.118403
# 83          81.104100            24.794168              77.887020
# 85          45.443750             9.906072              45.000000
# 180         37.903910             4.479099              24.710274
# 192         74.469082            33.283157              66.942101
# 201         67.513053            33.275590              51.535366
# 304         45.075450            12.306951              44.583177
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 75      30.398728     148.525562                145.378143  Abnormal
# 83      56.309932     151.839857                 65.214616  Abnormal
# 85      35.537678     163.071041                 20.315315  Abnormal
# 180     33.424811     157.848799                 33.607027  Abnormal
# 192     41.185925     146.466001                124.984406  Abnormal
# ...

# %%
df.pelvic_radius[(df.pelvic_radius<90)]=df.pelvic_radius.mean() # replace with mean value
# Out:
# <ipython-input-70-74750a52041e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pelvic_radius[(df.pelvic_radius<90)]=df.pelvic_radius.mean()

# %%
df.pelvic_radius[(df.pelvic_radius>145)]=df.pelvic_radius.mean() # replace with mean value
# Out:
# <ipython-input-72-0aa785ef6382>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pelvic_radius[(df.pelvic_radius>145)]=df.pelvic_radius.mean()

# %%
df[df.degree_spondylolisthesis>100]
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 71          86.900794            32.928168              47.794347
# 75          70.221452            17.542822              68.118403
# 76          86.753609            36.043016              69.221045
# 95          57.522356            33.647075              50.909858
# 115         60.496653             8.404475              48.384057
# 141         89.504947            17.542822              72.003423
# 143         60.626217            20.595958              64.535262
# 192         74.469082            33.283157              66.942101
# 197         58.828379            37.577873              51.930930
# 202         76.314028            17.542822              51.535366
# 205         80.111572            33.942432              51.535366
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 71      53.972627     135.075364                101.719092  Abnormal
# ...

# %%
df.degree_spondylolisthesis[(df.degree_spondylolisthesis>100)]=df.degree_spondylolisthesis.median() # replace with median value
# Out:
# <ipython-input-76-a4a2eb1c7b9e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.degree_spondylolisthesis[(df.degree_spondylolisthesis>100)]=df.degree_spondylolisthesis.median()

# %%
#outliers
box=df[['pelvic_incidence','pelvic_tilt_numeric', 'lumbar_lordosis_angle','sacral_slope','pelvic_radius','degree_spondylolisthesis']]
plt.figure(figsize=(5,10), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=7 : # as there are 9 columns in the data
        ax = plt.subplot(6,1,plotnumber)#plotting 6 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=20)#assign name to x-axis and set font-20
     
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
#scaling the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df[['pelvic_incidence','pelvic_tilt_numeric', 'lumbar_lordosis_angle','sacral_slope','pelvic_radius','degree_spondylolisthesis']]=sc.fit_transform(df[['pelvic_incidence','pelvic_tilt_numeric', 'lumbar_lordosis_angle','sacral_slope','pelvic_radius','degree_spondylolisthesis']])

# %%
df
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 0            0.193598             0.757774              -0.636637
# 1           -1.294002            -0.763805              -1.645770
# 2            0.553799             0.717078               0.088250
# 3            0.582655             1.013607              -0.311494
# 4           -0.632711            -0.813614              -1.417440
# ..                ...                  ...                    ...
# 305         -0.744993            -0.330692              -0.886202
# 306         -0.370582             0.534733              -1.354990
# 307          0.095469             0.775118              -0.182939
# 308         -0.909497            -0.930418              -0.500138
# 309         -1.617658            -1.371262              -0.841862
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 0       -0.184950      -1.816063                 -0.877977  Abnormal
# ...

# %% [markdown]
# ## Feature Selection

# %%
#change indepenent variable categorical to numerical
df['class'].replace('Abnormal',0,inplace=True)
df['class'].replace('Normal',1,inplace=True)

# %%
df
# Out:
#      pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# 0            0.193598             0.757774              -0.636637
# 1           -1.294002            -0.763805              -1.645770
# 2            0.553799             0.717078               0.088250
# 3            0.582655             1.013607              -0.311494
# 4           -0.632711            -0.813614              -1.417440
# ..                ...                  ...                    ...
# 305         -0.744993            -0.330692              -0.886202
# 306         -0.370582             0.534733              -1.354990
# 307          0.095469             0.775118              -0.182939
# 308         -0.909497            -0.930418              -0.500138
# 309         -1.617658            -1.371262              -0.841862
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis  class
# 0       -0.184950      -1.816063                 -0.877977      0
# ...

# %%
sns.heatmap(df.drop('class',axis=1).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model building

# %%
x=df.iloc[:,0:-1]

# %%
y=df['class']

# %%
y.value_counts()
# Out:
# 0    210
# 1    100
# Name: class, dtype: int64

# %%
#balance data
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_smote,y_smote=sm.fit_resample(x,y)

# %%
#split data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.25,random_state=42)

# %%
#balanced target variable
y_smote.value_counts()
# Out:
# 1    210
# 0    210
# Name: class, dtype: int64

# %%
#error state
from sklearn.neighbors import KNeighborsClassifier


error_rate=[]
for i in range(1,10+1):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    error_rate.append(np.mean(y_pred!=y_test))

# %%
#error rate graph
plt.figure(figsize=(5,5))
plt.title('error_rate vs K')
plt.plot(range(1,10+1),error_state,marker='o',markerfacecolor='red',markersize=5)
plt.xlabel('k')
plt.ylabel('error_rate')
plt.show()

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84        54
#            1       0.77      1.00      0.87        51
#
#     accuracy                           0.86       105
#    macro avg       0.89      0.86      0.86       105
# weighted avg       0.89      0.86      0.85       105

# %%
#performance metrices
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
acc #accuracy score
# Out:
# 0.8571428571428571

# %%
#accuracy score is 0.85 called as  best fit.
