# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Deepak Raj\Desktop\Data_Science\Machine Learning\Data\heart_disease.txt')

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 1     63    1       typical     145   233    1        2    150      0
# 2     67    1  asymptomatic     160   286    0        2    108      1
# 3     67    1  asymptomatic     120   229    0        2    129      1
# 4     37    1    nonanginal     130   250    0        0    187      0
# 5     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 299   45    1       typical     110   264    0        0    132      0
# 300   68    1  asymptomatic     144   193    1        0    141      0
# 301   57    1  asymptomatic     130   131    0        0    115      1
# 302   57    0    nontypical     130   236    0        2    174      0
# 303   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 1        2.3      3  0.0       fixed   No
# ...

# %% [markdown]
# ## Basic checks

# %%
#information about given dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 1 to 303
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 35.5+ KB

# %%
#shape
df.shape
# Out:
# (303, 14)

# %%
#No of rows in the given dataset is 303
#No of columns in the given dataset is 14

# %%
#statistics info about dataset
#numerical dataset
df.describe()
# Out:
#               Age         Sex      RestBP        Chol         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868  131.689769  246.693069    0.148515    0.990099
# std      9.038662    0.467299   17.599748   51.776918    0.356198    0.994971
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     48.000000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     56.000000    1.000000  130.000000  241.000000    0.000000    1.000000
# 75%     61.000000    1.000000  140.000000  275.000000    0.000000    2.000000
# max     77.000000    1.000000  200.000000  564.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
#catagorical data
df.describe(include='O')
# Out:
#            ChestPain    Thal  AHD
# count            303     301  303
# unique             4       3    2
# top     asymptomatic  normal   No
# freq             144     166  164

# %%
df.isnull().sum() #find null values
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
#No of null values in Ca is 4
#No of null values in Thal is 2

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## univariate Data

# %%
import sweetviz as sz
data=sz.analyze(df)
data.show_notebook()
# Out:
# ...
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
df.ChestPain.value_counts()
# Out:
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: ChestPain, dtype: int64

# %%
sns.countplot(x='ChestPain',data=df)
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='count'>

# %%
#No of asymptomic cheatpain in people is 144
#No of typical chestpain in people is 23
#No of nonanginal chestpain in people is 86
#No of nontypical chestpain in people is 50

# %%
df.Thal.value_counts()
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
sns.countplot(x='Thal',data=df)
# Out:
# <AxesSubplot:xlabel='Thal', ylabel='count'>

# %%
#No of normal Thal is 166
#No of reversablel Thal is 117
#No of fixed Thal is 18

# %% [markdown]
# ## Bivariate Data

# %%
data1=df[['Age','Sex','RestBP','Chol','Fbs','RestECG','MaxHR','ExAng','Oldpeak','Slope']]

# %%
df['AHD'].replace('Yes',1,inplace=True)
df['AHD'].replace('No',0,inplace=True)

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 1     63    1       typical     145   233    1        2    150      0
# 2     67    1  asymptomatic     160   286    0        2    108      1
# 3     67    1  asymptomatic     120   229    0        2    129      1
# 4     37    1    nonanginal     130   250    0        0    187      0
# 5     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 299   45    1       typical     110   264    0        0    132      0
# 300   68    1  asymptomatic     144   193    1        0    141      0
# 301   57    1  asymptomatic     130   131    0        0    115      1
# 302   57    0    nontypical     130   236    0        2    174      0
# 303   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 1        2.3      3  0.0       fixed    0
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')# defining  canvas size
plotnumber = 1 # initializing plotnumber variable to 1 it will maintain the count of how many graph is going to plot in canvas 


for column in data1: # iteration of columns / acessing the columns from  dataset 
    if plotnumber<=12 :     # as there are 11 columns in the data
        ax = plt.subplot(4,3,plotnumber)# plotting 11 graphs (3-rows,3-columns) ,plotnumber is for count  
        sns.histplot(x=data1[column],hue=df.AHD) ## it give frequency hue =value counts
        plt.xlabel(column,fontsize=20) #assigning name to x-axis and "name" font size is 20
        plt.ylabel('AHD',fontsize=20)#assigning name to y-axis and "name" font size is 20
    plotnumber+=1 # increment of plotnumber 
plt.show()# to show graph

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Age',hue='AHD',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
#The age between 58 to 64 people are detected high heart disease patients

# %%
sns.scatterplot(x='Age',y='RestBP',data=df,hue='AHD')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='RestBP'>

# %%
#RestBP is increasing with increasing in age

# %%
sns.countplot(x='Chol',hue='AHD',data=df)
# Out:
# <AxesSubplot:xlabel='Chol', ylabel='count'>

# %%
sns.scatterplot(x='Age',y='Chol',data=df,hue='AHD')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Chol'>

# %%
#Chol is incresing with increasing in Age

# %%
sns.scatterplot(x='Age',y='MaxHR',data=df,hue='AHD')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='MaxHR'>

# %%
#Heartbeat is decreasing with decreasing in Age
#Heart patient heart beat is decreasing in Age

# %%
sns.scatterplot(x='Age',y='RestBP',data=df,hue='AHD')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='RestBP'>

# %%
#RestBP is incresing with increaing in Age
#heart patient BP is high with incresing in Age

# %% [markdown]
# ## Data Preprocessing

# %%
#null values
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
#Ca null columns
df.loc[df['Ca'].isnull()==True,'Ca']=df.Ca.mode()[0] #replace null column with mode values

# %%
#replace categorical with numerical
df['Thal'].replace('normal',0,inplace=True) #replace normal as 0 
df['Thal'].replace('fixed',1,inplace=True)#replace fixed as 1
df['Thal'].replace('reversable',2,inplace=True) #replace reversable as 2

# %%
df.ChestPain.value_counts() #Chest pain counts
# Out:
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: ChestPain, dtype: int64

# %%
#replace categorical with numerical
df['ChestPain'].replace('typical',1,inplace=True) #replace typical as 1
df['ChestPain'].replace('nontypical',2,inplace=True)#replace nontypical as 2
df['ChestPain'].replace('nonanginal',3,inplace=True)#replace nonanginal as 3
df['ChestPain'].replace('asymptomatic',4,inplace=True)#replace asymptomaticl as 4
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1     63    1          1     145   233    1        2    150      0      2.3
# 2     67    1          4     160   286    0        2    108      1      1.5
# 3     67    1          4     120   229    0        2    129      1      2.6
# 4     37    1          3     130   250    0        0    187      0      3.5
# 5     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 299   45    1          1     110   264    0        0    132      0      1.2
# 300   68    1          4     144   193    1        0    141      0      3.4
# 301   57    1          4     130   131    0        0    115      1      1.2
# 302   57    0          2     130   236    0        2    174      0      0.0
# 303   38    1          3     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 1        3  0.0   1.0    0
# ...

# %%
df[df['Thal'].isnull()==True] #null value columns
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 88    53    0          3     128   216    0        2    115      0      0.0
# 267   52    1          4     128   204    1        0    156      1      1.0
#
#      Slope   Ca  Thal  AHD
# 88       1  0.0   NaN    0
# 267      2  0.0   NaN    1

# %%
df.loc[df['Thal'].isnull()==True,'Thal']=df.Thal.mode()[0]# replace null value with mode values

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
#outliers
box=df[['Age','RestBP', 'Chol','MaxHR']]
plt.figure(figsize=(5,10), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=6 : # as there are 9 columns in the data
        ax = plt.subplot(6,1,plotnumber)#plotting 6 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=20)#assign name to x-axis and set font-20
     
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
df[(df.RestBP>170)]
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 15    52    1          3     172   199    1        0    162      0      0.5
# 84    68    1          3     180   274    1        2    150      1      1.6
# 127   56    0          4     200   288    1        2    133      1      4.0
# 173   59    0          4     174   249    0        0    143      1      0.0
# 184   59    1          1     178   270    0        2    145      0      4.2
# 189   54    1          2     192   283    0        2    195      0      0.0
# 202   64    0          4     180   325    0        0    154      1      0.0
# 214   66    0          4     178   228    1        0    165      1      1.0
# 232   55    0          4     180   327    0        1    117      1      3.4
#
#      Slope   Ca  Thal  AHD
# 15       1  0.0   2.0    0
# 84       2  0.0   2.0    1
# 127      3  2.0   2.0    1
# 173      2  0.0   0.0    1
# 184      3  0.0   2.0    0
# 189      1  1.0   2.0    1
# ...

# %%
df.RestBP[(df.RestBP>170)]=df.RestBP.median() #replace RestBP outliers with median values
# Out:
# <ipython-input-47-945c625a3453>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.RestBP[(df.RestBP>170)]=df.RestBP.median()

# %%
df[(df.Chol>400)]
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 49    65    0          3     140   417    1        2    157      0      0.8
# 122   63    0          4     150   407    0        2    154      0      4.0
# 153   67    0          3     115   564    0        2    160      0      1.6
# 182   56    0          4     134   409    0        2    150      1      1.9
#
#      Slope   Ca  Thal  AHD
# 49       1  1.0   0.0    0
# 122      2  3.0   2.0    1
# 153      2  0.0   2.0    0
# 182      2  2.0   2.0    1

# %%
df.Chol[(df.Chol>400)]=df.Chol.median() #replace Chol outliers with median values
# Out:
# <ipython-input-49-0cb905845b2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Chol[(df.Chol>400)]=df.Chol.median()

# %%
df[(df.MaxHR<88)]
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 246   67    1          4     120   237    0        0     71      0      1.0
#
#      Slope   Ca  Thal  AHD
# 246      2  0.0   0.0    1

# %%
df.MaxHR[(df.MaxHR<90)]=df.MaxHR.mean() #replace MaxHR outliers with mean values
# Out:
# <ipython-input-51-e5702c98ffdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.MaxHR[(df.MaxHR<90)]=df.MaxHR.mean()

# %%
#after outlier treatment
box=df[['Age','RestBP', 'Chol','MaxHR']]
plt.figure(figsize=(5,10), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=6 : # as there are 9 columns in the data
        ax = plt.subplot(6,1,plotnumber)#plotting 3 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=20)#assign name to x-axis and set font-20
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
#scalar Transformation
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df[['RestBP','Chol','MaxHR']]=sc.fit_transform(df[['RestBP','Chol','MaxHR']])
df
# Out:
#      Age  Sex  ChestPain    RestBP      Chol  Fbs  RestECG     MaxHR  ExAng  \
# 1     63    1          1  0.977501 -0.240825    1        2 -0.003168      0
# 2     67    1          4  1.965435  0.925461    0        2 -1.903630      1
# 3     67    1          4 -0.669057 -0.328846    0        2 -0.953399      1
# 4     37    1          3 -0.010434  0.133267    0        0  1.671048      0
# 5     41    0          2 -0.010434 -0.878981    0        2  0.992312      0
# ..   ...  ...        ...       ...       ...  ...      ...       ...    ...
# 299   45    1          1 -1.327680  0.441343    0        0 -0.817652      0
# 300   68    1          4  0.911639 -1.121041    1        0 -0.410410      0
# 301   57    1          4 -0.010434 -2.485375    0        0 -1.586886      1
# 302   57    0          2 -0.010434 -0.174809    0        2  1.082810      0
# 303   38    1          3  0.516465 -1.517138    0        0  1.037561      0
#
#      Oldpeak  Slope   Ca  Thal  AHD
# ...

# %% [markdown]
# # Feature Selection

# %%
sns.heatmap(df.drop('AHD',axis=1).corr(),annot=True,cmap='cividis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Evaluation

# %%
x=df.iloc[:,0:-1] #independent variable
y=df.AHD #target variable

# %%
#balance x and y data
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_smote,y_smote=sm.fit_resample(x,y)

# %%
x_smote.shape #shape
# Out:
# (328, 13)

# %%
y_smote.shape #shape
# Out:
# (328,)

# %%
#split train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.25,random_state=42)

# %%
#apply LogisticRegression
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression() 
LR.fit(x_train,y_train)#fit train data
# Out:
# C:\Users\Deepak Raj\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(LR.intercept_) #line intercept
# Out:
# [-5.34649951]

# %%
y_pred=LR.predict(x_test) #y_pred

# %%
y_train_predict=LR.predict(x_train) #y_train_predict

# %%
#performance metrices
#accuracy score for train data
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_train,y_train_predict)
acc
# Out:
# 0.8821138211382114

# %%
#performance metrices
#accuracy score for test data
from sklearn.metrics import accuracy_score,f1_score
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7439024390243902

# %%
#classification report
#test data
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72        38
#            1       0.76      0.77      0.76        44
#
#     accuracy                           0.74        82
#    macro avg       0.74      0.74      0.74        82
# weighted avg       0.74      0.74      0.74        82

# %%
#classification report
#train data
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89       126
#            1       0.90      0.85      0.88       120
#
#     accuracy                           0.88       246
#    macro avg       0.88      0.88      0.88       246
# weighted avg       0.88      0.88      0.88       246

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[27, 11],
#        [10, 34]], dtype=int64)

# %%
#dataframe for confusion matrix
pd.crosstab(y_test,y_pred)
# Out:
# col_0   0   1
# AHD
# 0      27  11
# 1      10  34

# %%
#No of True positive is 27
#No of True positive is 11
#No of True positive is 10
#No of True positive is 34

# %%
y_prob=LR.predict_proba(x_test)[:,1] # predict proba for class 1
y_prob
# Out:
# array([0.84547005, 0.85498609, 0.65353456, 0.92136236, 0.01631243,
#        0.07655657, 0.98681853, 0.06622806, 0.39756289, 0.01362631,
#        0.98183788, 0.9753112 , 0.90726302, 0.25389905, 0.21371066,
#        0.98299008, 0.99692852, 0.67903363, 0.08295443, 0.04306132,
#        0.25099029, 0.72804521, 0.06345375, 0.5689398 , 0.03477471,
#        0.16682242, 0.82146852, 0.99798517, 0.02764932, 0.97467348,
#        0.01026167, 0.29284071, 0.51607277, 0.93989442, 0.84397473,
#        0.9745375 , 0.99024406, 0.66369393, 0.22584958, 0.09363959,
#        0.29894879, 0.33857481, 0.98244898, 0.64488162, 0.91498052,
#        0.99716573, 0.10225795, 0.92445726, 0.36499794, 0.48134929,
#        0.50271097, 0.48956205, 0.3224382 , 0.98810114, 0.09420359,
#        0.82609171, 0.18758595, 0.95787421, 0.64653361, 0.89651613,
#        0.08188096, 0.93516836, 0.83582783, 0.19455088, 0.26668832,
#        0.17545248, 0.87519597, 0.25683045, 0.9933238 , 0.03143519,
# ...

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve 
fpr,tpr,threshold=roc_curve(y_test,y_prob)

# %%
def plot_roc_curve(fpr, tpr):# function to plot roc curve
    plt.plot(fpr, tpr, color='orange', label='ROC')#line plot between fpr and tpr
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')# assigning name to  x axis
    plt.ylabel('True Positive Rate')# assigning name to y axis
    plt.title('Receiver Operating Characteristic (ROC) Curve')#assigning name to curve  
    plt.legend()#area describing the elements of the graph
    plt.show()#to show graph without location

# %%
plot_roc_curve(fpr, tpr)#plotting ruc curve
